# %% [markdown]
# Data Distionary

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Importing libraries   **

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline

# %% [markdown]
# **Importing Data **
# we have many option! i am loading data through drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
sales_df= ('/content/drive/MyDrive/sales_data_sample.csv')

# %%
sales_df= pd.read_csv(sales_df ,encoding='latin-1')
sales_df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
#Making a coping from orignal  data
data = sales_df.copy()

# %%
#checking the columns data.columns
Column_Names= data.columns
Column_Names
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE',
#        'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE',
#        'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME',
#        'DEALSIZE'],
#       dtype='object')

# %%
# to find in  data,rows and column
data.shape
#the first figure show the rows and 25 column
# Out:
# (2823, 25)

# %%
#for understanding and checking the data nature we simple find it through tail code
data.tail()
#State and Adress line we find as a null , as no information is provides in State and Adress line 2 rows
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#            ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 2818  12/2/2004 0:00   Shipped       4        12     2004  ...
# 2819  1/31/2005 0:00   Shipped       1         1     2005  ...
# 2820   3/1/2005 0:00  Resolved       1         3     2005  ...
# 2821  3/28/2005 0:00   Shipped       1         3     2005  ...
# 2822   5/6/2005 0:00   On Hold       2         5     2005  ...
#
#                ADDRESSLINE1  ADDRESSLINE2      CITY STATE POSTALCODE  COUNTRY  \
# ...

# %%
data.dtypes
# Out:
# ORDERNUMBER           int64
# QUANTITYORDERED       int64
# PRICEEACH           float64
# ORDERLINENUMBER       int64
# SALES               float64
# ORDERDATE            object
# STATUS               object
# QTR_ID                int64
# MONTH_ID              int64
# YEAR_ID               int64
# PRODUCTLINE          object
# MSRP                  int64
# PRODUCTCODE          object
# CUSTOMERNAME         object
# PHONE                object
# ADDRESSLINE1         object
# ADDRESSLINE2         object
# CITY                 object
# STATE                object
# POSTALCODE           object
# COUNTRY              object
# TERRITORY            object
# CONTACTLASTNAME      object
# CONTACTFIRSTNAME     object
# DEALSIZE             object
# dtype: object

# %%
#checking the type of data
data.isnull().sum()
# Out:
# ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# ADDRESSLINE2        2521
# CITY                   0
# STATE               1486
# POSTALCODE            76
# COUNTRY                0
# TERRITORY           1074
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %%
#drop the adress line 2 , state and postal code
data.drop(['ADDRESSLINE2', 'STATE', 'POSTALCODE'] , axis=1, inplace=True)
data.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... PRODUCTCODE  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...    S10_1678
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...    S10_1678
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...    S10_1678
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...    S10_1678
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...    S10_1678
#
#                CUSTOMERNAME             PHONE                   ADDRESSLINE1  \
# ...

# %%
data.info()
#for checking the null values in a data , some columns have null values.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   object
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
# ...

# %%
#To use decribe function to find out the descriptive statistics of th adata frame.
#like it proivde a quick overview of the statistical measure of the  numerical data.
data.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER  \
# count   2823.000000      2823.000000  2823.000000      2823.000000
# mean   10258.725115        35.092809    83.658544         6.466171
# std       92.085478         9.741443    20.174277         4.225841
# min    10100.000000         6.000000    26.880000         1.000000
# 25%    10180.000000        27.000000    68.860000         3.000000
# 50%    10262.000000        35.000000    95.700000         6.000000
# 75%    10333.500000        43.000000   100.000000         9.000000
# max    10425.000000        97.000000   100.000000        18.000000
#
#               SALES       QTR_ID     MONTH_ID     YEAR_ID         MSRP
# count   2823.000000  2823.000000  2823.000000  2823.00000  2823.000000
# mean    3553.889072     2.717676     7.092455  2003.81509   100.715551
# std     1841.865106     1.203878     3.656633     0.69967    40.187912
# min      482.130000     1.000000     1.000000  2003.00000    33.000000
# ...

# %%
data.isnull().sum()
# Out:
# ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# CITY                   0
# COUNTRY                0
# TERRITORY           1074
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %%
#for territory function to Fill USa territory i can use to replace value with north america instead of NA
data['TERRITORY'].fillna('North_America', inplace= True )
data.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... PRODUCTCODE  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...    S10_1678
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...    S10_1678
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...    S10_1678
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...    S10_1678
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...    S10_1678
#
#                CUSTOMERNAME             PHONE                   ADDRESSLINE1  \
# ...

# %%
data.isnull().sum()
# Out:
# ORDERNUMBER         0
# QUANTITYORDERED     0
# PRICEEACH           0
# ORDERLINENUMBER     0
# SALES               0
# ORDERDATE           0
# STATUS              0
# QTR_ID              0
# MONTH_ID            0
# YEAR_ID             0
# PRODUCTLINE         0
# MSRP                0
# PRODUCTCODE         0
# CUSTOMERNAME        0
# PHONE               0
# ADDRESSLINE1        0
# CITY                0
# COUNTRY             0
# TERRITORY           0
# CONTACTLASTNAME     0
# CONTACTFIRSTNAME    0
# DEALSIZE            0
# dtype: int64

# %%
#order date should be convert to Int

data['ORDERDATE'] = pd.to_datetime(data['ORDERDATE'])
data['ORDERDATE']= data['ORDERDATE'].astype(int)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   int64
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
# ...

# %%
data.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#              ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... PRODUCTCODE  \
# 0  1046044800000000000  Shipped       1         2     2003  ...    S10_1678
# 1  1052265600000000000  Shipped       2         5     2003  ...    S10_1678
# 2  1057017600000000000  Shipped       3         7     2003  ...    S10_1678
# 3  1061769600000000000  Shipped       3         8     2003  ...    S10_1678
# 4  1065744000000000000  Shipped       4        10     2003  ...    S10_1678
#
#                CUSTOMERNAME             PHONE                   ADDRESSLINE1  \
# ...

# %%
#checking the Duplicate rows in a data set.
data.duplicated().sum()

#for this it shows that in a data there is no duplicate rows
# Out:
# 0

# %%
#convert Adress line 1 to adressline for better understanding in a data frame
data.rename(columns={'ADDRESSLINE1' : 'ADRESSLINE'}, inplace=True)

# %%
data.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#              ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... PRODUCTCODE  \
# 0  1046044800000000000  Shipped       1         2     2003  ...    S10_1678
# 1  1052265600000000000  Shipped       2         5     2003  ...    S10_1678
# 2  1057017600000000000  Shipped       3         7     2003  ...    S10_1678
# 3  1061769600000000000  Shipped       3         8     2003  ...    S10_1678
# 4  1065744000000000000  Shipped       4        10     2003  ...    S10_1678
#
#                CUSTOMERNAME             PHONE                     ADRESSLINE  \
# ...

# %%
#merged two column Contact firtname and contactlastname into one coulmn Contact name
data['CONTACTNAME']= data['CONTACTFIRSTNAME']+ ' ' +data['CONTACTLASTNAME']
data.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#              ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0  1046044800000000000  Shipped       1         2     2003  ...
# 1  1052265600000000000  Shipped       2         5     2003  ...
# 2  1057017600000000000  Shipped       3         7     2003  ...
# 3  1061769600000000000  Shipped       3         8     2003  ...
# 4  1065744000000000000  Shipped       4        10     2003  ...
#
#                CUSTOMERNAME             PHONE                     ADRESSLINE  \
# 0         Land of Toys Inc.        2125557818        897 Long Airport Avenue
# ...

# %%
from pickle import TRUE
#drop the two column [CONTACTFIRSTNAME'] ['CONTACTLASTNAME]
data.drop (['CONTACTFIRSTNAME', 'CONTACTLASTNAME'], axis=1 , inplace= True)
data.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#              ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... MSRP  \
# 0  1046044800000000000  Shipped       1         2     2003  ...   95
# 1  1052265600000000000  Shipped       2         5     2003  ...   95
# 2  1057017600000000000  Shipped       3         7     2003  ...   95
# 3  1061769600000000000  Shipped       3         8     2003  ...   95
# 4  1065744000000000000  Shipped       4        10     2003  ...   95
#
#    PRODUCTCODE              CUSTOMERNAME             PHONE  \
# 0     S10_1678         Land of Toys Inc.        2125557818
# ...

# %%
print(data.columns)
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE',
#        'ADRESSLINE', 'CITY', 'COUNTRY', 'TERRITORY', 'DEALSIZE',
#        'CONTACTNAME'],
#       dtype='object')

# %%
#save the data and doenload in a csv format
data.to_csv('sales_data_sample_cleaned.csv', index=False)
#download
from google.colab import files
files.download('sales_data_sample_cleaned.csv')
